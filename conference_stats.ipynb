# %%
import pandas as pd

# %%
team_df=pd.read_csv("/Users/benpeyton/Desktop/vandy_boot_camp/Module_20/Segment-1/Resources/team.csv")
team_df
# Out:
#      Team Code              Name  Conference Code
# 0            5             Akron              875
# 1            8           Alabama              911
# 2            9               UAB            24312
# 3           28     Arizona State              905
# 4           29           Arizona              905
# ..         ...               ...              ...
# 234        817  Youngstown State              853
# 235       1068              Elon              912
# 236       1092      Gardner-Webb              826
# 237       2678   Ark.-Pine Bluff              916
# 238       2915           Wofford              912
#
# [239 rows x 3 columns]

# %%
conference_df=pd.read_csv("/Users/benpeyton/Desktop/vandy_boot_camp/Module_20/Segment-1/Resources/conference.csv")
conference_df
# Out:
#     Conference Code                         Name Subdivision
# 0               821    Atlantic Coast Conference         FBS
# 1             25354            Big 12 Conference         FBS
# 2               823          Big East Conference         FBS
# 3               827           Big Ten Conference         FBS
# 4             24312               Conference USA         FBS
# 5             99001                  Independent         FBS
# 6               875      Mid-American Conference         FBS
# 7              5486     Mountain West Conference         FBS
# 8               905        Pacific-10 Conference         FBS
# 9               911      Southeastern Conference         FBS
# 10              818          Sun Belt Conference         FBS
# 11              923  Western Athletic Conference         FBS
# 12              820                  Atlantic 10         FCS
# 13              825                      Big Sky         FCS
# ...

# %%
play_df=pd.read_csv("/Users/benpeyton/Desktop/vandy_boot_camp/Module_20/Segment-1/Resources/play.csv")
play_df.head()
# Out:
#          Game Code  Play Number  Period Number  Clock  Offense Team Code  \
# 0  690002820050901            1              1  900.0                690
# 1  690002820050901            2              1    NaN                 28
# 2  690002820050901            3              1    NaN                 28
# 3  690002820050901            4              1    NaN                 28
# 4  690002820050901            5              1    NaN                 28
#
#    Defense Team Code  Offense Points  Defense Points  Down  Distance  Spot  \
# 0                 28               0               0   NaN       NaN    65
# 1                690               0               0   1.0      10.0    80
# 2                690               0               0   2.0       8.0    78
# 3                690               0               0   3.0       8.0    78
# 4                690               0               0   3.0      19.0    89
#
#   Play Type  Drive Number  Drive Play
# ...

# %%
play_df=play_df.rename(columns={"Offense Team Code": "Team Code1", "Defense Team Code": "Team Code2"})
play_df.head()
# Out:
#          Game Code  Play Number  Period Number  Clock  Team Code1  Team Code2  \
# 0  690002820050901            1              1  900.0         690          28
# 1  690002820050901            2              1    NaN          28         690
# 2  690002820050901            3              1    NaN          28         690
# 3  690002820050901            4              1    NaN          28         690
# 4  690002820050901            5              1    NaN          28         690
#
#    Offense Points  Defense Points  Down  Distance  Spot Play Type  \
# 0               0               0   NaN       NaN    65   KICKOFF
# 1               0               0   1.0      10.0    80      RUSH
# 2               0               0   2.0       8.0    78      PASS
# 3               0               0   3.0       8.0    78   PENALTY
# 4               0               0   3.0      19.0    89      PASS
#
#    Drive Number  Drive Play
# 0           NaN         NaN
# 1           1.0         1.0
# ...

# %%
play_df = play_df.drop(columns=["Team Code2"])
play_df
# Out:
#               Game Code  Play Number  Period Number  Clock  Team Code1  \
# 0       690002820050901            1              1  900.0         690
# 1       690002820050901            2              1    NaN          28
# 2       690002820050901            3              1    NaN          28
# 3       690002820050901            4              1    NaN          28
# 4       690002820050901            5              1    NaN          28
# ...                 ...          ...            ...    ...         ...
# 135283  703065720060104          198              4   19.0         703
# 135284  703065720060104          199              4   19.0         703
# 135285  703065720060104          200              4   19.0         703
# 135286  703065720060104          201              4   19.0         657
# 135287  703065720060104          202              4    NaN         657
#
#         Offense Points  Defense Points  Down  Distance  Spot Play Type  \
# ...

# %%
play_df=play_df.rename(columns={"Team Code1": "Team Code"})
play_df.head()
# Out:
#          Game Code  Play Number  Period Number  Clock  Team Code  \
# 0  690002820050901            1              1  900.0        690
# 1  690002820050901            2              1    NaN         28
# 2  690002820050901            3              1    NaN         28
# 3  690002820050901            4              1    NaN         28
# 4  690002820050901            5              1    NaN         28
#
#    Offense Points  Defense Points  Down  Distance  Spot Play Type  \
# 0               0               0   NaN       NaN    65   KICKOFF
# 1               0               0   1.0      10.0    80      RUSH
# 2               0               0   2.0       8.0    78      PASS
# 3               0               0   3.0       8.0    78   PENALTY
# 4               0               0   3.0      19.0    89      PASS
#
#    Drive Number  Drive Play
# 0           NaN         NaN
# 1           1.0         1.0
# 2           1.0         1.0
# 3           1.0         0.0
# 4           1.0         1.0

# %%
# Combine the data into a single dataset.
complete_stats_df = pd.merge(team_df, play_df, on=["Team Code", "Team Code"])
complete_stats_df
# Out:
#         Team Code     Name  Conference Code         Game Code  Play Number  \
# 0               5    Akron              875     5055920050910            1
# 1               5    Akron              875     5055920050910           20
# 2               5    Akron              875     5055920050910           21
# 3               5    Akron              875     5055920050910           22
# 4               5    Akron              875     5055920050910           23
# ...           ...      ...              ...               ...          ...
# 135283       2915  Wofford              912  2915076820050910          166
# 135284       2915  Wofford              912  2915076820050910          167
# 135285       2915  Wofford              912  2915076820050910          168
# 135286       2915  Wofford              912  2915076820050910          169
# 135287       2915  Wofford              912  2915076820050910          170
#
# ...

# %%
complete_stats_df = complete_stats_df.sort_values(by=['Game Code', 'Play Number'])
complete_stats_df.head(50)
# Out:
#       Team Code        Name  Conference Code      Game Code  Play Number  \
# 9544         47  Ball State              875  5004720051105            1
# 773           5       Akron              875  5004720051105            2
# 774           5       Akron              875  5004720051105            3
# 775           5       Akron              875  5004720051105            4
# 776           5       Akron              875  5004720051105            5
# 9545         47  Ball State              875  5004720051105            6
# 9546         47  Ball State              875  5004720051105            7
# 9547         47  Ball State              875  5004720051105            8
# 9548         47  Ball State              875  5004720051105            9
# 9549         47  Ball State              875  5004720051105           10
# 9550         47  Ball State              875  5004720051105           11
# 777           5       Akron              875  5004720051105           12
# ...

# %%
# Combine the data into a single dataset.
complete_stats_df = pd.merge(complete_stats_df, conference_df, on=["Conference Code", "Conference Code"])
complete_stats_df.head(50)
# Out:
#     Team Code      Name_x  Conference Code      Game Code  Play Number  \
# 0          47  Ball State              875  5004720051105            1
# 1           5       Akron              875  5004720051105            2
# 2           5       Akron              875  5004720051105            3
# 3           5       Akron              875  5004720051105            4
# 4           5       Akron              875  5004720051105            5
# 5          47  Ball State              875  5004720051105            6
# 6          47  Ball State              875  5004720051105            7
# 7          47  Ball State              875  5004720051105            8
# 8          47  Ball State              875  5004720051105            9
# 9          47  Ball State              875  5004720051105           10
# 10         47  Ball State              875  5004720051105           11
# 11          5       Akron              875  5004720051105           12
# ...

# %%
conference_stats_df = complete_stats_df.drop(columns=["Conference Code", "Name_y", "Subdivision_x"])
conference_stats_df
# Out:
#         Team Code       Name_x        Game Code  Play Number  Period Number  \
# 0              47   Ball State    5004720051105            1              1
# 1               5        Akron    5004720051105            2              1
# 2               5        Akron    5004720051105            3              1
# 3               5        Akron    5004720051105            4              1
# 4               5        Akron    5004720051105            5              1
# ...           ...          ...              ...          ...            ...
# 135283        670  Texas State  670069720050922          190              4
# 135284        670  Texas State  670069720050922          191              4
# 135285        670  Texas State  670069720050922          192              4
# 135286        670  Texas State  670069720050922          193              4
# 135287        670  Texas State  670069720050922          194              4
#
# ...

# %%
conference_stats_df=conference_stats_df.rename(columns={"Name_x": "Team Name", "Name": "Conference", "Subdivision_y": "Subdivision"})
conference_stats_df
# Out:
#         Team Code    Team Name        Game Code  Play Number  Period Number  \
# 0              47   Ball State    5004720051105            1              1
# 1               5        Akron    5004720051105            2              1
# 2               5        Akron    5004720051105            3              1
# 3               5        Akron    5004720051105            4              1
# 4               5        Akron    5004720051105            5              1
# ...           ...          ...              ...          ...            ...
# 135283        670  Texas State  670069720050922          190              4
# 135284        670  Texas State  670069720050922          191              4
# 135285        670  Texas State  670069720050922          192              4
# 135286        670  Texas State  670069720050922          193              4
# 135287        670  Texas State  670069720050922          194              4
#
# ...
